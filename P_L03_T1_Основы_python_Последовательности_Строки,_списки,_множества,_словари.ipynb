# %% [markdown]
# # Задание Lite

# %% [markdown]
# 1. Из всех методов списка (list) выбрать 5 тех, которые по вашему мнению используются чаще всего
# 2. Написать их через запятую с параметрами
# 3. Повторить процедуру для словарей (dict), множеств (set), строк (str)

# %% [markdown]
# ### Дополнительные материалы

# %% [markdown]
# Методы:
# - https://pythonworld.ru/tipy-dannyx-v-python/spiski-list-funkcii-i-metody-spiskov.html
# - https://pythonworld.ru/tipy-dannyx-v-python/stroki-funkcii-i-metody-strok.html
# - https://pythonworld.ru/tipy-dannyx-v-python/mnozhestva-set-i-frozenset.html
# - https://pythonworld.ru/tipy-dannyx-v-python/slovari-dict-funkcii-i-metody-slovarej.html

# %% [markdown]
# # РЕШЕНИЕ

# %% [markdown]
# ## **🔘 Задания 1, 2, 3**

# %% [markdown]
# ### методы списка (list):
#
# - list.append(x),
# - list.sort([key=функция]),
# - list.pop([i]),
# - list.insert(i, x),
# - list.count(x)

# %% [markdown]
# ### методы словарей (dict):
#
# - dict.items(),
# - dict.keys(),
# - dict.values(),
# - dict.update([other]),
# - dict.popitem()

# %% [markdown]
# ### методы множеств (set):
#
# - set.add(elem),
# - set.remove(elem),
# - set.pop(),
# - set.update(other, ...),
# - set.intersection_update(other, ...)

# %% [markdown]
# ### методы строк (str):
#
# - S.split(символ),
# - S.join(список),
# - len(S),
# - S.strip([chars]),
# - S[i:j:step]

# %% [markdown]
# ## **🔘 4. (МОДУЛЬ 1) Создать новый проект, в нем создать модуль 1seq.py.**
#
# - **https://raw.githubusercontent.com/dnp34/Python_L03/main/1seq.py**

# %% [markdown]
# **Задание:**
# - Пользователь вводит количество элементов будущего списка
# - После этого по очереди по одной вводит любые цифры
# - Сохранить цифры в список
# - Отсортировать список по возрастанию и вывести на экран

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **🔘 5. (МОДУЛЬ 2) создать модуль 2seq.py.**
#
# - **https://raw.githubusercontent.com/dnp34/Python_L03/main/2seq.py**

# %% [markdown]
# **Задание:**
# - Пользователь вводит любые цифры через запятую
# - Сохранить цифры в список
# - Получить новый список в котором будут только уникальные элементы исходного - - (уникальным считается символ, который встречается в исходном списке только 1 раз)
# - Вывести новый список на экран
# - Порядок цифр в новом списке не важен

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **🔘 6. (МОДУЛЬ 3) В проекте создать новый модуль 3seq.py.**
#
# - **https://raw.githubusercontent.com/dnp34/Python_L03/main/3seq.py**

# %% [markdown]
# **Задание:**
#
# - Пользователь вводит элементы 1-го списка (по очереди как в МОДУЛЬ 1 или вместе как в МОДУЛЬ 2)
# - Затем он вводит элементы 2-го списка
# - Удалить из первого списка элементы присутствующие во 2-ом и вывести результат на экран

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **🔘 7. (МОДУЛЬ 4) В проекте создать новый модуль victory.py**
#
# - **https://raw.githubusercontent.com/dnp34/Python_L03/main/victory.py**

# %% [markdown]
# **Задание**
# - Написать или улучшить программу Викторина из предыдущего дз
# - Есть 10 известных людей и их даты рождения в формате '02.01.1988' ('dd.mm.yyyy') - пока использовать строку
# - Программа выбирает из этих 10-и 5 случайных людей,
# - это можно реализовать с помощью модуля random и функции sample

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Проект на GitHub или Google Colab:**
# - **``git clone https://github.com/dnp34/Python_L03.git``**
# - **https://colab.research.google.com/drive/1_kwwoX4xEmpZiGDg-57YrU8MevXYXUAk?usp=sharing**
